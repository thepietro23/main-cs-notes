# %%
print('Hello')

# %%
# Selection sort
# ascending
def selection_sort(arr):
    n = len(arr)
    
    for i in range(0,n):
        min_inx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_inx]:
                arr[min_inx], arr[j] = arr[j], arr[min_inx]
            
    return arr
            

arr = [5,7,8,4,1,6,9,2]
selection_sort(arr)

# %%
# descending
def selection_sort_desc(arr):
    n = len(arr)
    for i in range(n):
        max_idx = i
        for j in range(i+1, n):
            if arr[j] > arr[max_idx]:
                arr[max_idx], arr[j] = arr[j], arr[max_idx]
    return arr

selection_sort_desc(arr)

# %%
# Bubble sort >> Adjacent swap

def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(i+1, n):
            if arr[i] > arr[j]:
                arr[i], arr[j] = arr[j], arr[i]

    return arr

bubble_sort(arr)

# %%
# Logic - Average Case / Worst Case
def bubble_sort_cd(arr):
    n = len(arr)
    for i in range(n-2, -1, -1):
        for j in range(0, i+1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

    return arr

bubble_sort_cd(arr)

# %%
# Logic - Best Case
def bubble_sort_cd(arr):
    n = len(arr)
    for i in range(n-2, -1, -1):
        is_swap = False
        for j in range(0, i+1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
                is_swap = True

        if is_swap == False:
            break
        
    return arr

bubble_sort_cd(arr)

# %%
# Insertion Sort >> M uske correct position pr rakhunga

def insertion_sort(arr):
    n = len(arr)
    for i in range(1,n):
        key = arr[i]
        j = i-1
        while j >= 0 and arr[j] > key:
                arr[j+1] = arr[j]
                j -= 1
        arr[j+1] = key

    return arr

arr = [5,7,8,4,1,6,9,2]
insertion_sort(arr)

# %%
# Merge Sort

def merge_arr(left, right):
    result = []
    i, j = 0, 0
    m, n = len(left), len(right)
    while(i < m and j < n):
        if left[i] <= right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    if i < m:
        while i < m:
            result.append(left[i])
            i += 1

    if j < n:
        while j < n:
            result.append(right[j])
            j += 1

    return result

def merge_sort(arr):
    n = len(arr)
    if len(arr) <= 1:
        return arr
    
    mid = len(arr)//2

    left_arr = arr[:mid]
    right_arr = arr[mid:]

    left_arr = merge_sort(left_arr)
    right_arr = merge_sort(right_arr)

    return merge_arr(left_arr, right_arr)

 

arr = [3,1,2,4,1,5,2,6,4]
merge_sort(arr)

# %%
arr = [3,1,6,2,4,8,7]
merge_sort(arr)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# QUICK SORT

def partition(arr, low, high):
    pivot = arr[low]
    i = low
    j = high
    while i < j:
        while arr[i] <= pivot and i <= high-1:
            i += 1
        while arr[j] > pivot and j >= low+1:
            j -= 1

        if i < j:
            arr[i], arr[j] = arr[j], arr[i]

    arr[low], arr[j] = arr[j], arr[low]
    return j

def quick_sort(arr, low, high):
    if low < high:
        partition_index = partition(arr,low,high)
        quick_sort(arr, low, partition_index-1)
        quick_sort(arr,partition_index+1, high)




arr = [4,1,7,6,3,2,8]
quick_sort(arr)

# %%
print("hi")
